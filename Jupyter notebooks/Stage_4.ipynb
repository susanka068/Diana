# %%
import json
import math

# %%
file = open("/home/subho/Downloads/stage_2.json", "r")
data = json.load(file)

# %%
detail_stats = {}
rev_summ_stats = {}

# %%
def calculate_trendiness(rating_div, oldest_rev, newest_rev):
    # Assuming maximum customer count for this apparel as 10000
    max_cnt = 10000
    if len(rating_div) == 0:
        return None
    
    # Assuming weightage scale [-2, -1, 0, 0.5, 1]
    score = rating_div['5'] * 1 + rating_div['4']*0.5 + rating_div['3']*0
    score += rating_div['2'] * (-1) + rating_div['1']*-2
    
    #normalizing score
    score /= rating_div["1"] + rating_div["2"] + rating_div["3"] + rating_div["4"] + rating_div["5"]
    score *= max_cnt
     
    if oldest_rev is None:
        # Since, generally the newest product have few ratings
        time_diff = 5
    else :
        # time_diff is the number of days since introduction of the product
        time_diff = (newest_rev - oldest_rev)/86400
    
    # More rating in less time means more trendy
    score /= time_diff
    
    return score

# %%
def calculate_score

# %%
modified_json = []
for item in data:
    # Copy everything except oldest_rev, newest_rev, 
    # rating_div
    item_new = {}

    item_new["id"] = item["id"]
    item_new["title"] = item["title"]
    item_new["rating_div"] = item["rating_div"]
    item_new["image"] = item["image"]
    item_new["rev_summ"] = item["rev_summ"]
    item_new["detail"] = item["detail"]
    
    rating_div = item["rating_div"]
    oldest_rev = item["oldest_rev"]
    newest_rev = item["newest_rev"]
     
    score = calculate_trendiness(rating_div, oldest_rev, newest_rev)
    if score is None :
        continue
    item_new["score"] = score
    modified_json.append(item_new)

# %%
modified_json
# Out:
# [{'id': 1,
#   'title': 'Whisper Cotton Ribbed Crewneck T-Shirt',
#   'rating_div': {'5': 64, '4': 15, '3': 6, '2': 7, '1': 9},
#   'image': 'https://n.nordstrommedia.com/id/sr3/965ca924-3d01-4240-a196-1b000d939869.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['trendy',
#     'great',
#     'short',
#     'thin',
#     'not flattering',
#     'baggy',
#     'basic'],
#    'fabric': ['rough', 'scratchy'],
#    'fit': ['great']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'knit': ['slub'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'hem': ['curved']},
#   'score': 58.27797969670385},
#  {'id': 2,
#   'title': 'Rounded V-Neck T-Shirt',
#   'rating_div': {'5': 76, '4': 28, '3': 13, '2': 8, '1': 7},
#   'image': 'https://n.nordstrommedia.com/id/sr3/8bc59c4a-7992-4df0-aae6-a9b46404a03c.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['fits  well',
#     'soft',
#     'scratchy',
#     'comfortable',
#     'thin',
#     'little holes',
#     'versatile',
#     'happened not sure',
#     'simple',
#     'loose',
#     'flattering'],
#    'color': ['gorgeous', 'thin', 'fine'],
#    'fabric': ['thin', 'fine'],
#    'holes': ['little', 'tiny'],
#    'purchase': ['great']},
#   'detail': {'neckline': ['v-neck'],
#    'shirt': ['tee'],
#    'knit': ['slub'],
#    'sleeve': ['short'],
#    'fabric': ['modal', 'cotton']},
#   'score': 46.410046410046405},
#  {'id': 3,
#   'title': 'Whisper Cotton V-Neck Pocket Tee',
#   'rating_div': {'5': 65, '4': 16, '3': 9, '2': 5, '1': 5},
#   'image': 'https://n.nordstrommedia.com/id/sr3/c74c4515-d608-4a63-b784-197053928f4f.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'bottom': ['different holes'],
#    'shirt': ['sad',
#     'perfect',
#     'fits better',
#     'white',
#     'disappointed',
#     'not more'],
#    'material': ['cheap'],
#    'color': ['great', 'pretty']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['cotton'],
#    'neckline': ['v-neck'],
#    'knit': ['slub'],
#    'sleeve': ['short']},
#   'score': 3.8183015141540486},
#  {'id': 4,
#   'title': 'Ringer V-Neck T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/af8d9e1d-2736-43f2-93ca-12122dbbf4c8.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'design': ['ringer'],
#    'shirt': ['tee'],
#    'neckline': ['v-neck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'rayon']},
#   'score': 2000.0},
#  {'id': 5,
#   'title': 'Raglan Crop T-Shirt',
#   'rating_div': {'5': 66, '4': 11, '3': 13, '2': 4, '1': 6},
#   'image': 'https://n.nordstrommedia.com/id/sr3/a8e5d287-7091-44af-ad94-6417ce4b1b1f.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['comfy',
#     'short',
#     'great',
#     'casual',
#     'affordable',
#     '’s  also',
#     'super',
#     'causal',
#     'cute'],
#    'Shirt': ['beefy'],
#    'price': ['right', 'good'],
#    'crop': ['light', 'little', 'easy'],
#    'quality': ['nice'],
#    'roomy': ['true'],
#    'edges': ['raw cut'],
#    'material': ['softest'],
#    'time': ['first'],
#    'merchandise': ['good quality']},
#   'detail': {'length': ['crop'],
#    'shirt': ['top'],
#    'design': ['raw edge'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'cotton']},
#   'score': 88.09523809523812},
#  {'id': 7,
#   'title': 'Knit Wrap Front Top',
#   'rating_div': {'5': 20, '4': 60, '3': 0, '2': 0, '1': 20},
#   'image': 'https://n.nordstrommedia.com/id/sr3/9cd88a68-d352-4a5f-8407-ced2c5086139.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['top'],
#    'knit': ['stretch'],
#    'neckline': ['v-neck'],
#    'sleeve': ['short'],
#    'fabric': ['spandex']},
#   'score': 200.0},
#  {'id': 9,
#   'title': 'Short Sleeve Crewneck Tee',
#   'rating_div': {'5': 62, '4': 21, '3': 10, '2': 5, '1': 2},
#   'image': 'https://n.nordstrommedia.com/id/sr3/869e11ce-7e99-41c3-81b1-dbd470ff2f34.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['clingy',
#     'great',
#     'not worth',
#     'thin',
#     'nice',
#     'little',
#     'basic'],
#    'white': ['little see', 'sheer'],
#    'see': ['little'],
#    'material': ['horrible', 'high quality'],
#    'quality': ['great'],
#    'colors': ['great'],
#    'red': ['great color'],
#    'color': ['great'],
#    'Fit': ['perfect']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['pima', 'modal', 'cotton'],
#    'knit': ['jersey'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 226.78571428571428},
#  {'id': 10,
#   'title': 'Eyelet Detail Baby Doll Top',
#   'rating_div': {'5': 53, '4': 23, '3': 14, '2': 5, '1': 5},
#   'image': 'https://n.nordstrommedia.com/id/sr3/2ea1c6a5-c03c-4a28-97d7-bb68ac406b64.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['light weight',
#     'flowy fit',
#     'comfy',
#     'cute style',
#     'runs large',
#     'delicate',
#     'cold',
#     'like',
#     'true',
#     'thin',
#     'wonderful',
#     'awesome',
#     '’s pretty',
#     'pleased',
#     'feels disposable',
#     'perfect',
#     'cute',
#     'basic',
#     '’s true'],
#    'xs': ['perfect'],
#    'color': ['great'],
#    'weight': ['light'],
#    'Quality': ['average'],
#    'Delivery': ['quick']},
#   'detail': {'shirt': ['tee'],
#    'design': ['lace'],
#    'sleeve': ['short'],
#    'fabric': ['cotton']},
#   'score': 61.111111111111114},
#  {'id': 11,
#   'title': 'Pointelle Top',
#   'rating_div': {'5': 60, '4': 0, '3': 20, '2': 20, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/05f92cb0-81a0-4707-9f0e-3049a306e7d7.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['top'],
#    'neckline': ['v-neck'],
#    'sleeve': ['long'],
#    'fabric': ['polyester', 'rayon']},
#   'score': 800.0},
#  {'id': 13,
#   'title': 'Scoop Neck Baby T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/e0d10b50-0b71-47a4-b850-2209e40e4226.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['scooped'],
#    'sleeve': ['short'],
#    'fabric': ['spandex', 'cotton']},
#   'score': 2000.0},
#  {'id': 14,
#   'title': 'Flutter Sleeve T-Shirt',
#   'rating_div': {'5': 70, '4': 30, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/6c18b57a-a99e-4b4c-8311-ab87b254a19b.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['great',
#     'dressy',
#     'beautiful',
#     'flattering',
#     'good',
#     'little',
#     'looked big',
#     'ran big',
#     'feminine'],
#    'sleeves': ['perfect amount'],
#    'amount': ['perfect'],
#    'neck': ['not deep'],
#    'fabric': ['heavier', 'thicker', 'nice', 'little'],
#    'Fit': ['true'],
#    'Clematis': ['darker'],
#    'fit': ['perfect']},
#   'detail': {'fabric': ['cotton'],
#    'neckline': ['v-neck'],
#    'shirt': ['tee'],
#    'knit': ['jersey'],
#    'design': ['ruffle'],
#    'sleeve': ['short']},
#   'score': 2125.0},
#  {'id': 17,
#   'title': 'Clarity Tee',
#   'rating_div': {'5': 59, '4': 15, '3': 15, '2': 9, '1': 3},
#   'image': 'https://n.nordstrommedia.com/id/sr3/220fd561-af93-4a19-a7b6-978fb8e2ac5b.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'cotton': ['thin'],
#    'quality': ['good'],
#    'shirt': ['soft',
#     'comfy',
#     'thin',
#     '’s comfortable',
#     '’s shapeless',
#     'oversized',
#     'lightweight',
#     '’s loose'],
#    'colors': ['new'],
#    'length': ['great'],
#    'shirts': ['free people'],
#    'shape': ['forgiving'],
#    'Fabric': ['thin']},
#   'detail': {'shirt': ['tee'],
#    'knit': ['slub'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'cotton']},
#   'score': 79.67202970297029},
#  {'id': 19,
#   'title': 'Crewneck Cotton Blend Top',
#   'rating_div': {'5': 65, '4': 13, '3': 9, '2': 4, '1': 9},
#   'image': 'https://n.nordstrommedia.com/id/sr3/1551939b-26e5-4771-876b-2629821e9980.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['soft',
#     'true',
#     'favorite',
#     'nice',
#     'adorable',
#     'basic',
#     '’s true'],
#    'length': ['long'],
#    'material': ['soft', 'thick', 'not thin'],
#    'chic': ['classic'],
#    'size': ['larger'],
#    'blend': ['durable', 'comfortable'],
#    'price': ['reasonable'],
#    'Shirts': ['comfortable'],
#    'T': ['fitting', 'basic', 'great']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['modal', 'cotton']},
#   'score': 78.57142857142857},
#  {'id': 21,
#   'title': 'Crewneck T-Shirt',
#   'rating_div': {'5': 25, '4': 25, '3': 25, '2': 0, '1': 25},
#   'image': 'https://n.nordstrommedia.com/id/sr3/e2c69e36-221a-437e-94f5-f563b4a38eaf.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': -250.0},
#  {'id': 23,
#   'title': 'Studio Tee',
#   'rating_div': {'5': 56, '4': 11, '3': 22, '2': 11, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/300c132d-7284-4cc6-a3f1-e6db4afaed81.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirts': ['comfy', 'cozy'],
#    'shirt': ['’s cute', '’s perfect', 'good', 'fun', '’s  definitely'],
#    'Quality': ['good'],
#    'print': ['fun'],
#    'Shirt': ['perfect'],
#    'blue': ['pretty'],
#    'fabric': ['good weight cotton']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['cotton'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 27.005347593582886},
#  {'id': 24,
#   'title': 'Ava T-Shirt',
#   'rating_div': {'5': 71, '4': 16, '3': 7, '2': 4, '1': 1},
#   'image': 'https://n.nordstrommedia.com/id/sr3/92727abb-a144-4154-a1df-d19fd745f370.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['clingy',
#     'comfortable',
#     'big',
#     'not worth',
#     'runs large',
#     '’s comfortable',
#     'perfect',
#     'available',
#     'seem expensive',
#     'fantastic',
#     '’s  long',
#     'flattering'],
#    'fabric': ['quality'],
#    'fit': ['great'],
#    'sleeves': ['huge', 'perfect'],
#    'material': ['nice'],
#    'cut': ['slim'],
#    'shirts': ['stylish', 'casual workout', 'comfortable'],
#    'one': ['perfect'],
#    'Fit': ['good length'],
#    'length': ['perfect', 'good'],
#    'price': ['good'],
#    'Zella': ['great shirt'],
#    'quality': ['great'],
#    'neck': ['perfect']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['v-neck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'spandex'],
#    'design': ['lace']},
#   'score': 351.13035113035113},
#  {'id': 27,
#   'title': 'Pretty Lace Ribbed Crop Top',
#   'rating_div': {'5': 50, '4': 40, '3': 5, '2': 0, '1': 5},
#   'image': 'https://n.nordstrommedia.com/id/sr3/b485eff6-e17c-408c-91b6-21b271737a72.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['fits  well',
#     'comfy',
#     'everyday',
#     'short',
#     'fit  perfectly',
#     'not sure',
#     'casual',
#     'transparent',
#     'fun',
#     'small',
#     'not transparent',
#     'lightweight',
#     'not dressy',
#     'washed  well',
#     'cute',
#     'nice',
#     'fits  perfectly'],
#    'price': ['great'],
#    'piece': ['flattering']},
#   'detail': {'length': ['crop'],
#    'shirt': ['top'],
#    'neckline': ['v-neck'],
#    'knit': ['rib-knit'],
#    'design': ['lace'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'cotton']},
#   'score': 146.34146341463415},
#  {'id': 28,
#   'title': 'Ballet Neck Cotton & Modal Knit Elbow Sleeve Tee',
#   'rating_div': {'5': 70, '4': 17, '3': 7, '2': 3, '1': 3},
#   'image': 'https://n.nordstrommedia.com/id/sr3/e1c35d6d-fb67-4182-9eed-a35a24447373.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['soft',
#     'true',
#     'lovely',
#     'comfortable',
#     'hot',
#     'happy',
#     'stays cool',
#     'longer',
#     '’s great',
#     'good',
#     '’s  longer',
#     'perfect',
#     'fit'],
#    'steal': ['total'],
#    'build': ['athletic'],
#    'medium': ['relaxed'],
#    'version': ['great'],
#    'shirts': ['perfect'],
#    'color': ['coral', 'beautiful'],
#    'fit': ['soft', 'versatile'],
#    'colors': ['different', 'more'],
#    'blue': ['striped'],
#    'sleeve': ['perfect'],
#    'teal': ['beautiful']},
#   'detail': {'shirt': ['tee'], 'fabric': ['modal', 'cotton']},
#   'score': 267.30769230769226},
#  {'id': 29,
#   'title': 'Ruffle Sleeve Cotton Blend Top',
#   'rating_div': {'5': 60, '4': 17, '3': 10, '2': 7, '1': 7},
#   'image': 'https://n.nordstrommedia.com/id/sr3/dd21ef37-65b2-4283-a585-78d62cd2b9b3.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['fits true',
#     'snug',
#     "n't different",
#     'cute',
#     'fits  perfectly'],
#    'bra': ['purple shirt'],
#    'SIZE': ['same', 'exact'],
#    'sleeves': ['ruffled'],
#    'white': ['cute'],
#    'color': ['vibrant'],
#    'fit': ['comfortable', 'great'],
#    'piece': ['staple']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['modal', 'cotton'],
#    'neckline': ['v-neck'],
#    'design': ['ruffle'],
#    'sleeve': ['short']},
#   'score': 102.23848471803703},
#  {'id': 31,
#   'title': 'Slub Jersey Camp Shirt',
#   'rating_div': {'5': 55, '4': 27, '3': 5, '2': 5, '1': 9},
#   'image': 'https://n.nordstrommedia.com/id/sr3/d0931a79-08fe-49fb-a3a5-520f190fa0a2.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['soft',
#     'wise',
#     'fine',
#     'comfortable',
#     'long tail',
#     'flattering',
#     'nice',
#     'cute',
#     '’s fine',
#     'short sleeve',
#     'lay nicer',
#     'more'],
#    'Material': ['soft'],
#    'thread': ['brown'],
#    'buttons': ['functional', 'not brown', 'good'],
#    'color': ['great', 'good'],
#    'weight': ['light'],
#    'purchase': ['horrible'],
#    'fabric': ['soft', 'flattering'],
#    'cotton': ['stiff'],
#    'itselt': ['soft drop'],
#    'cling': ['good thing'],
#    'thing': ['good']},
#   'detail': {'fabric': ['cotton'],
#    'hem': ['curved'],
#    'knit': ['slub', 'jersey']},
#   'score': 11.824017047374028},
#  {'id': 33,
#   'title': 'Everyday Crop Crewneck Tee',
#   'rating_div': {'5': 43, '4': 24, '3': 13, '2': 11, '1': 9},
#   'image': 'https://n.nordstrommedia.com/id/sr3/3cd7905d-90f3-4fe5-b58e-efd07eae040a.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'crop': ['great'],
#    'length': ['perfec'],
#    'shirt': ['become bothersome',
#     'short',
#     'great',
#     'inexpensive',
#     'fit  well',
#     'okay',
#     'basic'],
#    'thing': ['only'],
#    'neck': ['awkward gap'],
#    'cut': ['great'],
#    'basic': ['perfect'],
#    'Shirt': ['basic', 'great']},
#   'detail': {'length': ['crop'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['cotton']},
#   'score': 76.47058823529412},
#  {'id': 34,
#   'title': 'Pintuck Yoke Flutter Sleeve Tee',
#   'rating_div': {'5': 50, '4': 0, '3': 17, '2': 33, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/c792c6c8-24a1-4ad2-aeeb-8bbce330d950.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'Caslon': ['much flutter'],
#    'shirt': ['cute detailing', 'fun', 'nice', 'longer'],
#    'sleeves': ['giant', 'big'],
#    'length': ['little']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['cotton'],
#    'knit': ['slub'],
#    'pleat': ['pattern'],
#    'design': ['lace', 'ruffle']},
#   'score': 22.66666666666667},
#  {'id': 36,
#   'title': 'Strength Performance T-Shirt',
#   'rating_div': {'5': 61, '4': 19, '3': 11, '2': 8, '1': 1},
#   'image': 'https://n.nordstrommedia.com/id/sr3/5c65355b-a8b8-47eb-b8a6-2e4cc1f74705.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'color': ['pretty'],
#    'shirt': ['lightweighshirt', 'great', 'good'],
#    'weight': ['light'],
#    'colors': ['darker'],
#    'cut': ['comfortable'],
#    'services': ['excellent']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'spandex']},
#   'score': 163.51351351351352},
#  {'id': 37,
#   'title': '3-Pack Slim Fit Crewneck T-Shirts',
#   'rating_div': {'5': 71, '4': 16, '3': 3, '2': 3, '1': 6},
#   'image': 'https://n.nordstrommedia.com/id/sr3/74b42ff9-a3e9-46a5-b4b5-4dd8cbdc3e3e.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['fit', 'comfy', 'good'],
#    'quality': ['amazing', 'great'],
#    'product': ['fitting', 'great'],
#    'problem': ['enough', 'only', 'big'],
#    'arms': ['little', 'big'],
#    'fit': ['slim', 'great', 'good'],
#    'value': ['good'],
#    'clothing': ['best']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'design': ['logo'],
#    'sleeve': ['short']},
#   'score': 102.6134359467693},
#  {'id': 38,
#   'title': 'Georgia Crewneck T-Shirt',
#   'rating_div': {'5': 84, '4': 10, '3': 3, '2': 2, '1': 1},
#   'image': 'https://n.nordstrommedia.com/id/sr3/a11780b8-8a8e-4f7f-b50b-17bb8f9b1429.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'color': ['gorgeous', 'soft', 'not heavy'],
#    'shirt': ['short', 'hang dry', 'comfortable', 'great'],
#    'versions': ['newer', 'thinner', 'tighter'],
#    'material': ['nice look', 'thinner'],
#    'quality': ['amazing'],
#    'bit': ['little'],
#    'colors': ['many', 'great']},
#   'detail': {'fabric': ['pima', 'cotton'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 1062.5},
#  {'id': 46,
#   'title': 'Scoop Neck Cotton Blend Tee',
#   'rating_div': {'5': 50, '4': 17, '3': 33, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/d05b1a98-48ed-47a4-aab6-90329749f1df.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'fabric': ['soft', 'nice'],
#    'neckline': ["n't high"],
#    'women': ['rare', 'older'],
#    'shirt': ['run little',
#     'look fresh',
#     'great',
#     'beautiful',
#     'look beautiful',
#     'perfect',
#     'small',
#     'run small',
#     'casual',
#     '’s more'],
#    'medium': ['solid'],
#    'color': ['beautiful'],
#    'shirts': ['favorite'],
#    'job': ['good'],
#    'Quality': ['thin', 'nice'],
#    'quality': ['medium', 'comfortable']},
#   'detail': {'shirt': ['tee'], 'fabric': ['modal', 'cotton']},
#   'score': 17.256637168141594},
#  {'id': 49,
#   'title': 'Eyelet Detail Baby Doll Top',
#   'rating_div': {'5': 53, '4': 23, '3': 14, '2': 5, '1': 5},
#   'image': 'https://n.nordstrommedia.com/id/sr3/962768ba-de41-42a6-814e-0085c34a5c8a.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['light weight',
#     'flowy fit',
#     'comfy',
#     'cute style',
#     'runs large',
#     'delicate',
#     'cold',
#     'like',
#     'true',
#     'thin',
#     'wonderful',
#     'awesome',
#     '’s pretty',
#     'pleased',
#     'feels disposable',
#     'perfect',
#     'cute',
#     'basic',
#     '’s true'],
#    'xs': ['perfect'],
#    'color': ['great'],
#    'weight': ['light'],
#    'Quality': ['average'],
#    'Delivery': ['quick']},
#   'detail': {'shirt': ['tee'], 'design': ['lace'], 'fabric': ['cotton']},
#   'score': 61.111111111111114},
#  {'id': 50,
#   'title': 'Sweetheart Neck Bodysuit',
#   'rating_div': {'5': 33, '4': 19, '3': 17, '2': 19, '1': 13},
#   'image': 'https://n.nordstrommedia.com/id/sr3/c5dde707-29e7-4c76-8afb-65860859b363.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['’s cute',
#     'comes  high',
#     '’s sheer',
#     'comfortable',
#     '’s  still',
#     'not hard'],
#    'price': ['great'],
#    'fabric': ['flattering cut', 'solid', 'great'],
#    'cut': ['flattering'],
#    'crotch': ['solid fabric'],
#    'bodysuit': ['cute', 'flattering'],
#    'quality': ['good']},
#   'detail': {'knit': ['jersey'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'spandex']},
#   'score': -4.420084865629421},
#  {'id': 51,
#   'title': 'Ava Puff Sleeve Bodysuit',
#   'rating_div': {'5': 25, '4': 50, '3': 25, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/d8e760d3-9871-4aa0-8a30-477dbbbb3819.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'neckline': ['scooped'],
#    'sleeve': ['short'],
#    'fabric': ['cotton']},
#   'score': 1000.0},
#  {'id': 53,
#   'title': 'Eyelet Flutter Sleeve T-Shirt',
#   'rating_div': {'5': 43, '4': 36, '3': 14, '2': 7, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/207efc55-a805-4043-b4ab-190f03ff61c5.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['expensive',
#     'beautiful details',
#     'cut  so',
#     'favorite',
#     'cut narrow',
#     'tight',
#     '’s not long',
#     'comfortable',
#     '’s long',
#     'looks nice',
#     '’s cute',
#     'staple',
#     'new',
#     'fluttery',
#     'looks  now',
#     'cute',
#     'flattering',
#     'good',
#     '’s little',
#     '’s loose',
#     'more'],
#    'material': ['thinner'],
#    'sleeves': ['much fabric', 'cute', 'fun'],
#    'length': ['good'],
#    'reason': ['only'],
#    'fit': ['little', 'tight'],
#    'color': ['nice'],
#    'purchase': ['good'],
#    'fabric': ['cute', 'nice quality'],
#    'cotton': ['high quality']},
#   'detail': {'shirt': ['tee'],
#    'sleeve': ['short'],
#    'neckline': ['crewneck'],
#    'fabric': ['rayon', 'cotton']},
#   'score': 180.0},
#  {'id': 54,
#   'title': "KISS Spirit of '76 Crop Graphic Tee",
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/56a192d2-fa54-4a9d-ad77-ae22f9b1e284.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'length': ['crop'], 'shirt': ['tee'], 'fabric': ['cotton']},
#   'score': 2000.0},
#  {'id': 58,
#   'title': 'Ballet Neck Cotton & Modal Knit Elbow Sleeve Tee',
#   'rating_div': {'5': 70, '4': 17, '3': 7, '2': 3, '1': 3},
#   'image': 'https://n.nordstrommedia.com/id/sr3/efcfb35f-6c81-4ccc-b0d6-6fac552be574.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['soft',
#     'true',
#     'lovely',
#     'comfortable',
#     'hot',
#     'happy',
#     'stays cool',
#     'longer',
#     '’s great',
#     'good',
#     '’s  longer',
#     'perfect',
#     'fit'],
#    'steal': ['total'],
#    'build': ['athletic'],
#    'medium': ['relaxed'],
#    'version': ['great'],
#    'shirts': ['perfect'],
#    'color': ['coral', 'beautiful'],
#    'fit': ['soft', 'versatile'],
#    'colors': ['different', 'more'],
#    'blue': ['striped'],
#    'sleeve': ['perfect'],
#    'teal': ['beautiful']},
#   'detail': {'shirt': ['tee'], 'fabric': ['modal', 'cotton']},
#   'score': 267.30769230769226},
#  {'id': 68,
#   'title': 'Heart Print Tee',
#   'rating_div': {'5': 50, '4': 50, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/aba2f165-12ae-486c-9825-0d44dd5b96d6.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['modal', 'cotton'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 1500.0},
#  {'id': 69,
#   'title': 'Heathered Stretch Pocket T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/57a8903c-95a3-4215-b594-0b62296dd959.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'spandex', 'cotton']},
#   'score': 2000.0},
#  {'id': 70,
#   'title': 'Ballet Neck Cotton & Modal Knit Elbow Sleeve Tee',
#   'rating_div': {'5': 57, '4': 13, '3': 10, '2': 17, '1': 3},
#   'image': 'https://n.nordstrommedia.com/id/sr3/c10cfc4c-d829-49b6-9c0f-3a1b09d8482c.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'ribbed': ['fine'],
#    'price': ['great'],
#    'shirt': ['not long',
#     'dark',
#     'basic',
#     'comfortable',
#     'large',
#     'not clingy',
#     '’s short',
#     'perfect',
#     '’s little',
#     'fit',
#     'cute',
#     'nice',
#     'flattering'],
#    'length': ['perfect', 'flattering'],
#    'product': ['durable', 'comfortable'],
#    'fabric': ['heavier'],
#    'opening': ['not wide'],
#    'sleeves': ['perfect length'],
#    'amount': ['comfortable'],
#    'thing': ['bad'],
#    'color': ['rich blue'],
#    'blue': ['rich'],
#    'fit': ['similar'],
#    'material': ['perfect', 'flattering']},
#   'detail': {'shirt': ['tee'], 'fabric': ['modal', 'cotton']},
#   'score': 58.69565217391305},
#  {'id': 72,
#   'title': 'Shirttail Tunic',
#   'rating_div': {'5': 31, '4': 15, '3': 27, '2': 19, '1': 8},
#   'image': 'https://n.nordstrommedia.com/id/sr3/25375538-1ccc-4ff9-80b1-b3faefd6798e.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'color': ['happy yellow', 'drab mustard', 'sunny yellow'],
#    'yellow': ['happy', 'sunny'],
#    'mustard': ['drab'],
#    'shirt': ['went  back',
#     'scratchy',
#     'great',
#     'bad',
#     'look good',
#     'casual',
#     'perfect',
#     'available',
#     'long',
#     'sized',
#     'oversized',
#     'hold  well',
#     'cute',
#     'basic',
#     'sheer'],
#    'find': ['great'],
#    'fabric': ["n't soft"],
#    'fit': ['great']},
#   'detail': {'fabric': ['polyester', 'cotton'],
#    'neckline': ['v-neck'],
#    'sleeve': ['long']},
#   'score': 0.9831460674157305},
#  {'id': 73,
#   'title': 'Crewneck Mesh Top',
#   'rating_div': {'5': 56, '4': 11, '3': 22, '2': 0, '1': 11},
#   'image': 'https://n.nordstrommedia.com/id/sr3/b8cf098a-d321-4e9d-969f-4680e6fd15a2.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'cut': ['fitted', 'flattering'],
#    'neck': ['flattering'],
#    'shoe': ['cute'],
#    'straps': ['tight'],
#    'material': ['soft', 'comfortable'],
#    'way': ['nice'],
#    'shirt': ['itchy', 'perfect', 'tight', 'flattering']},
#   'detail': {'shirt': ['top'],
#    'design': ['print', 'pattern', 'mesh'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester']},
#   'score': 77.45098039215686},
#  {'id': 75,
#   'title': 'Classic Fit T-Shirt',
#   'rating_div': {'5': 77, '4': 9, '3': 2, '2': 2, '1': 9},
#   'image': 'https://n.nordstrommedia.com/id/sr3/6dbce7e6-f1ec-4ecd-ba24-64940b6ad7e8.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['soft',
#     'comfy',
#     'comfortable',
#     'worth',
#     'breathable'],
#    'quality': ['great']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 270.09222661396575},
#  {'id': 76,
#   'title': 'Rounded V-Neck T-Shirt',
#   'rating_div': {'5': 76, '4': 28, '3': 13, '2': 8, '1': 7},
#   'image': 'https://n.nordstrommedia.com/id/sr3/1cd03b24-9183-4e6e-94a4-78de56260af3.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['fits  well',
#     'soft',
#     'scratchy',
#     'comfortable',
#     'thin',
#     'little holes',
#     'versatile',
#     'happened not sure',
#     'simple',
#     'loose',
#     'flattering'],
#    'color': ['gorgeous', 'thin', 'fine'],
#    'fabric': ['thin', 'fine'],
#    'holes': ['little', 'tiny'],
#    'purchase': ['great']},
#   'detail': {'fabric': ['modal', 'cotton'],
#    'neckline': ['v-neck'],
#    'shirt': ['tee'],
#    'sleeve': ['short']},
#   'score': 46.410046410046405},
#  {'id': 79,
#   'title': 'Breezy Tie Back Top',
#   'rating_div': {'5': 67, '4': 17, '3': 0, '2': 0, '1': 17},
#   'image': 'https://n.nordstrommedia.com/id/sr3/60f3454f-47dd-4c3d-b776-1fe95c3679f2.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['perfect', 'runs large', 'sheer'],
#    'color': ['beautiful'],
#    'time': ['hot'],
#    'fabric': ['lightweight'],
#    'medium': ['huge']},
#   'detail': {'shirt': ['top'],
#    'sleeve': ['long'],
#    'neckline': ['crewneck'],
#    'fabric': ['polyester']},
#   'score': 79.01751713632902},
#  {'id': 80,
#   'title': 'Be Proud by BP. Gender Inclusive Tie Dye T-Shirt',
#   'rating_div': {'5': 60, '4': 20, '3': 20, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/b8ee88ae-901f-477f-b4b7-d96bab691460.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['bright',
#     'bummed',
#     'roomy',
#     'different',
#     'more',
#     'fun',
#     'casual',
#     'fits oversized'],
#    'colors': ['great'],
#    'material': ['soft'],
#    'tho': ['soft', 'lightweight']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'color': ['tie dye'],
#    'design': ['lace', 'pattern'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 583.3333333333334},
#  {'id': 83,
#   'title': 'Collegiate Cotton Graphic Tee',
#   'rating_div': {'5': 73, '4': 18, '3': 0, '2': 9, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/86d871c2-1d82-4817-895a-83dbc27a4cc4.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['overall',
#     'looked huge',
#     'soft',
#     'run large',
#     'looks great',
#     'comfortable',
#     '’s oversized',
#     'fits great',
#     'perfect',
#     'looked sloppy',
#     'oversized',
#     'boxy fit',
#     'cute',
#     'nice'],
#    'love': ['soft cotton'],
#    'XS': ['little round', 'big round'],
#    'Sleeves': ['long'],
#    'one': ['black']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['cotton'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 82.02247191011236},
#  {'id': 85,
#   'title': 'Dolman Sleeve Cotton Blend Pullover',
#   'rating_div': {'5': 33, '4': 22, '3': 20, '2': 8, '1': 16},
#   'image': 'https://n.nordstrommedia.com/id/sr3/7d9ad452-4149-4e16-90ae-92d4fb47c112.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'neckline': ['more'],
#    'band': ['snug'],
#    'fabric': ['nice', 'loose', 'nicer'],
#    'fit': ['relaxed'],
#    'shirt': ['disappointing',
#     'great',
#     'feels big',
#     'reminiscent',
#     'look sexy',
#     '’s  long',
#     'longer',
#     'softer',
#     'nice',
#     'looked bad'],
#    'cut': ['weird'],
#    'sweashirt': ['light', 'wonderful'],
#    'color': ['wonderful'],
#    'beck': ['wide'],
#    'hips': ['slim'],
#    'look': ['sexy hip'],
#    'waist': ['n’t tight'],
#    'quality': ['nice', 'nicer'],
#    'design': ['cute'],
#    'white': ['larger'],
#    'flaw': ['big']},
#   'detail': {'fabric': ['modal', 'cotton'], 'sleeve': ['long']},
#   'score': 7.482229704451928},
#  {'id': 87,
#   'title': 'Favorite Daughter Graphic Tee',
#   'rating_div': {'5': 61, '4': 13, '3': 9, '2': 4, '1': 13},
#   'image': 'https://n.nordstrommedia.com/id/sr3/c40d3d73-6ba7-4f0d-a267-445ae3dfb48a.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['soft',
#     'comfy',
#     'surprised',
#     'comfortable',
#     'to.oversized not boxy',
#     'to.oversized huge',
#     'great',
#     'relaxed',
#     'fit',
#     'cute'],
#    'Material': ['substantial'],
#    'washes': ['nice'],
#    'medium': ['perfect', 'tight'],
#    'gift': ['surprise'],
#    'daughter': ['only', 'favorite'],
#    'material': ["n't soft", 'soft'],
#    'thinness': ['unfortunate'],
#    'lettering': ['blueish color', 'lovely', 'weird color', 'graphic'],
#    'color': ['blueish', 'weird'],
#    'fit': ['loose'],
#    'Small': ['not tight']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['polyester', 'rayon', 'triblend', 'cotton'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 34.09090909090909},
#  {'id': 88,
#   'title': 'Long Sleeve Turtleneck',
#   'rating_div': {'5': 59, '4': 23, '3': 10, '2': 5, '1': 4},
#   'image': 'https://n.nordstrommedia.com/id/sr3/02174047-feb6-4138-8a36-49ddc5ab8a31.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'staple': ['great'],
#    'material': ['soft', 'nice'],
#    'weight': ['right'],
#    'shirt': ['soft',
#     'glad',
#     'looks good',
#     'not bulky',
#     'comfortable',
#     'great',
#     'snug',
#     '’s baggy',
#     'perfect',
#     'available',
#     'sleek'],
#    'neck': ['different'],
#    'arms': ['long', 'comfortable'],
#    'turtleneck': ['perfect length', 'soft length'],
#    'length': ['soft', 'perfect'],
#    'side': ['only']},
#   'detail': {'knit': ['stretch'],
#    'sleeve': ['long'],
#    'neckline': ['turtle'],
#    'fabric': ['rayon', 'spandex']},
#   'score': 63.967070864389804},
#  {'id': 89,
#   'title': 'Emelyn Tonic Tee',
#   'rating_div': {'5': 80, '4': 0, '3': 0, '2': 0, '1': 20},
#   'image': 'https://n.nordstrommedia.com/id/sr3/458fd49d-ce53-4433-aa45-4bf8e0f826f1.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['cotton'],
#    'neckline': ['v-neck'],
#    'knit': ['jersey'],
#    'design': ['raw edge'],
#    'sleeve': ['short']},
#   'score': 800.0},
#  {'id': 90,
#   'title': 'Tie Dye Rib Baby T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/050cbb92-17b2-4db1-9e89-82339bb0833b.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['scooped'],
#    'sleeve': ['short'],
#    'fabric': ['rayon', 'polyester', 'spandex']},
#   'score': 2000.0},
#  {'id': 93,
#   'title': 'Heritage Script Logo T-Shirt',
#   'rating_div': {'5': 71, '4': 12, '3': 4, '2': 6, '1': 6},
#   'image': 'https://n.nordstrommedia.com/id/sr3/2226169c-e498-40f4-a191-b90d05d91611.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['happy'], 'material': ['nice'], 'thing': ['only']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 73.57525876044394},
#  {'id': 94,
#   'title': 'Dri-FIT Legend T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/5e870584-8f15-46b6-95c3-7d48d78267ef.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'knit': ['jersey'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester']},
#   'score': 2000.0},
#  {'id': 97,
#   'title': 'Mixed Media Twist Front Top',
#   'rating_div': {'5': 53, '4': 12, '3': 12, '2': 12, '1': 12},
#   'image': 'https://n.nordstrommedia.com/id/sr3/fd16161c-6f69-49e1-8153-5f4dfd001a7b.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'quality': ['boxy', 'poor', 'shapeless'],
#    'blouse': ['oversized'],
#    'shirt': ['great', 'tight fitting', 'runs little', 'runs big', 'loose'],
#    'color': ['beautiful', 'pink'],
#    'material': ['nice', 'n’t heavy', 'lightweight', 'n’t perfect']},
#   'detail': {'neckline': ['v-neck'],
#    'sleeve': ['short'],
#    'fabric': ['modal', 'polyester']},
#   'score': 108.43941537010845},
#  {'id': 98,
#   'title': 'Crewneck T-Shirt',
#   'rating_div': {'5': 58, '4': 22, '3': 11, '2': 6, '1': 3},
#   'image': 'https://n.nordstrommedia.com/id/sr3/cb3f68c9-838f-42c7-a97b-f03e0014295a.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'fabric': ['poor quality', 'soft'],
#    'quality': ['decent', 'poor'],
#    'length': ['short', 'right'],
#    'material': ['comfortable'],
#    'shirt': ['not awesome',
#     'look  long',
#     'great',
#     '’re soft',
#     '’s great',
#     'good',
#     '’s comfortable',
#     '’s soft',
#     'okay',
#     'white',
#     'fit',
#     'simple',
#     'basic',
#     'sheer'],
#    'touch': ['cool'],
#    'deal': ['great'],
#    'Shirt': ['simple']},
#   'detail': {'fabric': ['modal', 'cotton'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 172.7272727272727},
#  {'id': 101,
#   'title': 'The Rolling Stones Graphic Tee',
#   'rating_div': {'5': 80, '4': 0, '3': 20, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/49379b30-aff2-45af-b2c8-a6f2d715b0fe.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'design': ['logo', 'graphic'],
#    'knit': ['jersey'],
#    'color': ['tie dye'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['cotton']},
#   'score': 1600.0},
#  {'id': 103,
#   'title': 'Cotton Jersey Crewneck T-Shirt',
#   'rating_div': {'5': 71, '4': 17, '3': 10, '2': 2, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/be240d37-67c7-4096-b066-d79d3814925e.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'cotton': ['thick', 'nice'],
#    'logo': ['cute', 'simple'],
#    'one': ['little bit'],
#    'bit': ['little'],
#    'fit': ['slim', 'great', 'good'],
#    'shirt': ['soft',
#     'comfortable',
#     'real',
#     'happy',
#     'runs little',
#     'stylish',
#     'fits great',
#     'small',
#     'runs small',
#     'run small',
#     'cute',
#     'nice'],
#    'quality': ['high', 'excellent'],
#    'Shirt': ['high quality']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'knit': ['jersey'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 71.75925925925925},
#  {'id': 104,
#   'title': 'Tradewind Pocket Performance T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/6d48f6c5-01ec-4233-b0c0-f7183f8737fa.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester']},
#   'score': 2000.0},
#  {'id': 105,
#   'title': 'Rounded V-Neck Tee',
#   'rating_div': {'5': 51, '4': 23, '3': 9, '2': 7, '1': 11},
#   'image': 'https://n.nordstrommedia.com/id/sr3/05fadb64-67ee-4de7-a73c-b5bf83cc7579.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'fabric': ['soft', 'thin'],
#    'cut': ['right'],
#    'shirt': ['comfortable',
#     'short',
#     'thin material',
#     'affordable',
#     'nice material',
#     'perfect',
#     'little',
#     'fitting',
#     'cute',
#     'nice',
#     'fit perfect',
#     'flattering'],
#    'Shirt': ['comfortable'],
#    'fit': ['perfect'],
#    'material': ['thin', 'nice'],
#    'item': ['round', 'staple']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['v-neck'],
#    'knit': ['jersey'],
#    'design': ['print'],
#    'sleeve': ['short'],
#    'fabric': ['modal', 'cotton']},
#   'score': 36.85368536853685},
#  {'id': 106,
#   'title': 'Embroidered Eyelet Knit Top',
#   'rating_div': {'5': 63, '4': 26, '3': 5, '2': 5, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/1215f670-f8ef-458e-9123-421ec67b432d.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'sleeves': ['fun', 'flattering'],
#    'tassels': ['fun', 'heavy', 'flattering'],
#    'tassles': ['nice feature'],
#    'feature': ['nice'],
#    'shirt': ['soft',
#     'n’t flattering',
#     'boxy',
#     'cute',
#     'disappointed',
#     'holds open'],
#    'color': ['nice brick'],
#    'brick': ['nice'],
#    'v': ['significant'],
#    'cut': ['different'],
#    'flutter': ['pronounced']},
#   'detail': {'shirt': ['top'],
#    'neckline': ['v-neck'],
#    'design': ['ruffle'],
#    'sleeve': ['short'],
#    'fabric': ['modal', 'cotton']},
#   'score': 217.32476277930823},
#  {'id': 109,
#   'title': 'Square Neck T-Shirt',
#   'rating_div': {'5': 30, '4': 20, '3': 10, '2': 0, '1': 40},
#   'image': 'https://n.nordstrommedia.com/id/sr3/0ea3a8da-89e2-4628-b5ec-77903f47fd38.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'disappointment': ['big'],
#    'shirt': ['comfortable', 'dressy', 'perfect', 'tight', 'cute', 'loose'],
#    'bust': ['large'],
#    'quality': ['better', 'great', 'good'],
#    'pink': ['pink'],
#    'decision': ['good']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['square'],
#    'sleeve': ['short'],
#    'fabric': ['modal', 'cotton']},
#   'score': -1333.3333333333333},
#  {'id': 110,
#   'title': 'Horoscope Graphic Crop Tee',
#   'rating_div': {'5': 0, '4': 0, '3': 0, '2': 0, '1': 100},
#   'image': 'https://n.nordstrommedia.com/id/sr3/6a8066f0-c7ad-4ab6-926b-5523bc419cfb.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'design': ['themed'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['cotton']},
#   'score': -4000.0},
#  {'id': 112,
#   'title': 'Strato Slim Fit Crewneck T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/2aa0fee0-2fd6-4274-bd4e-4506beee9714.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'material': ['soft'],
#    'color': ['flattering'],
#    'shirt': ['soft', 'comfortable', 'fit', 'wears  well', 'blue'],
#    'shorts': ['blue dunes']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'spandex']},
#   'score': 23.752969121140143},
#  {'id': 113,
#   'title': 'Gathered Mesh Top',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/38384552-b8f0-4c5c-a7b0-e20a92e2005c.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['top'],
#    'neckline': ['v-neck'],
#    'design': ['ruch', 'print', 'mesh'],
#    'sleeve': ['long'],
#    'fabric': ['polyester']},
#   'score': 2000.0},
#  {'id': 114,
#   'title': 'Garment Dye Studio T-Shirt',
#   'rating_div': {'5': 33, '4': 0, '3': 33, '2': 0, '1': 33},
#   'image': 'https://n.nordstrommedia.com/id/sr3/662015f8-4566-4bb6-8bb8-b4c5daa661d7.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'color': ['garment-dyed'],
#    'neckline': ['scooped'],
#    'sleeve': ['short']},
#   'score': -666.6666666666666},
#  {'id': 115,
#   'title': 'Cozy Top',
#   'rating_div': {'5': 74, '4': 14, '3': 8, '2': 1, '1': 4},
#   'image': 'https://n.nordstrommedia.com/id/sr3/f6402745-d7da-4ffc-82e0-8a88add4526e.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['light weight',
#     'soft',
#     '’s nice',
#     'lovely',
#     'comfortable',
#     'great',
#     'pilly',
#     'cozier',
#     'thin',
#     'cozy',
#     'not tight',
#     'little',
#     'not thin',
#     'cute'],
#    'weight': ['light'],
#    'Cozy': ['right'],
#    'quality': ['good'],
#    'value': ['great']},
#   'detail': {'shirt': ['top'],
#    'neckline': ['crewneck'],
#    'sleeve': ['long'],
#    'fabric': ['rayon', 'polyester', 'spandex']},
#   'score': 229.95847971893963},
#  {'id': 116,
#   'title': 'Mesh Around Crop Top',
#   'rating_div': {'5': 79, '4': 11, '3': 5, '2': 0, '1': 5},
#   'image': 'https://n.nordstrommedia.com/id/sr3/3193c9c4-93f6-48a4-b32e-aff5b55f2b69.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'daughter': ['old', '16-year'],
#    'shirt': ['’s airy',
#     '’s cute',
#     'true',
#     'comfy',
#     'big',
#     'great',
#     '’s perfect',
#     '’s cool',
#     'not great',
#     'super',
#     'not revealing',
#     'small',
#     'little',
#     'versatile',
#     'cute',
#     'heavier',
#     'flattering'],
#    'summer': ['casual'],
#    'Sleeves': ['loose'],
#    'length': ['great'],
#    'color': ['green', 'cute'],
#    'mesh': ['trendy'],
#    'sleeves': ['longer']},
#   'detail': {'length': ['crop'],
#    'shirt': ['top'],
#    'design': ['mesh'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'cotton']},
#   'score': 135.45454545454547},
#  {'id': 125,
#   'title': 'Def Leppard Graphic Tee',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/eff3e461-6ca0-4fe6-a976-e8c6a72afc05.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['cotton'],
#    'design': ['graphic'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 2000.0},
#  {'id': 126,
#   'title': 'Puff Sleeve Top',
#   'rating_div': {'5': 40, '4': 10, '3': 20, '2': 10, '1': 20},
#   'image': 'https://n.nordstrommedia.com/id/sr3/c3d45ed6-ab31-4560-b8f2-05e8a248bbd7.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['true',
#     'not tight',
#     'not puffy',
#     '’s comfortable',
#     'adorable',
#     'cute',
#     'more'],
#    'sleeves': ['puffy'],
#    'cut': ['great'],
#    'color': ['brighter'],
#    'sleeve': ['nice detail'],
#    'detail': ['nice']},
#   'detail': {'shirt': ['top'],
#    'fabric': ['rayon', 'cotton'],
#    'sleeve': ['short']},
#   'score': -8.19672131147541},
#  {'id': 127,
#   'title': 'The Perfect Camo Linen Tee',
#   'rating_div': {'5': 53, '4': 7, '3': 13, '2': 7, '1': 20},
#   'image': 'https://n.nordstrommedia.com/id/sr3/32a09490-5143-4b56-9091-09c3198fac56.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'quality': ['nice', 'good'],
#    'shirt': ['glad',
#     'comfy',
#     'true',
#     'happy',
#     'feel  differently',
#     'drapes  well',
#     'scratchy-',
#     'cute',
#     '’s  definitely'],
#    'fit': ['perfect'],
#    'fabric': ['good quality'],
#    'color': ['great'],
#    'greens': ['pigmented', 'pleasing'],
#    'material': ['not comfortable', 'rough'],
#    'Sanctuary': ['great fabric'],
#    'addition': ['welcome']},
#   'detail': {'shirt': ['tee'],
#    'design': ['camo'],
#    'fabric': ['linen'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 14.84375},
#  {'id': 128,
#   'title': 'Whale Pocket T-Shirt',
#   'rating_div': {'5': 80, '4': 0, '3': 0, '2': 20, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/531f105b-3462-47e3-a66d-8a476a22d8e7.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 1200.0},
#  {'id': 129,
#   'title': 'Scallop Slub Crewneck T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/b5dae07a-e743-4b37-af1f-3b317810a7d5.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'fabric': ['cotton'],
#    'hem': ['curved'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 2000.0},
#  {'id': 130,
#   'title': 'The Perfect Camo Linen Tee',
#   'rating_div': {'5': 53, '4': 7, '3': 13, '2': 7, '1': 20},
#   'image': 'https://n.nordstrommedia.com/id/sr3/e749f7b4-9d3f-4c6a-9acf-50206507d51d.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'quality': ['nice', 'good'],
#    'shirt': ['glad',
#     'comfy',
#     'true',
#     'happy',
#     'feel  differently',
#     'drapes  well',
#     'scratchy-',
#     'cute',
#     '’s  definitely'],
#    'fit': ['perfect'],
#    'fabric': ['good quality'],
#    'color': ['great'],
#    'greens': ['pigmented', 'pleasing'],
#    'material': ['not comfortable', 'rough'],
#    'Sanctuary': ['great fabric'],
#    'addition': ['welcome']},
#   'detail': {'shirt': ['tee'],
#    'design': ['camo'],
#    'fabric': ['linen'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 14.84375},
#  {'id': 132,
#   'title': 'Happens for a Reason Graphic Tee',
#   'rating_div': {'5': 14, '4': 7, '3': 7, '2': 36, '1': 36},
#   'image': 'https://n.nordstrommedia.com/id/sr3/e34b6144-ac05-425e-9589-236974d90917.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'quality': ['awful', 'great'],
#    'shirt': ['not worth',
#     'looks old',
#     'cropped',
#     'runs small',
#     'cute',
#     'tough',
#     'running small'],
#    'material': ['good']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['cotton']},
#   'score': -161.60714285714286},
#  {'id': 134,
#   'title': 'Crewneck T-Shirt',
#   'rating_div': {'5': 71, '4': 21, '3': 0, '2': 7, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/c4158378-bd6e-4dc1-8d85-b3277b75e66b.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'quality': ['material', 'good'],
#    'shirt': ['comfortable', 'pricey', '’s chic', 'little', '’s simple'],
#    'item': ['higher end'],
#    'accent': ['simple', 'not big'],
#    'service': ['amazing'],
#    'outside': ['soft']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'design': ['logo'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 12.059699559699558},
#  {'id': 137,
#   'title': 'Legend 2.0 Dri-FIT Training T-Shirt',
#   'rating_div': {'5': 70, '4': 19, '3': 4, '2': 1, '1': 6},
#   'image': 'https://n.nordstrommedia.com/id/sr3/29e75cb5-705a-4acc-b9cd-f017299e906e.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'complaint': ['main'],
#    'shirt': ['soft',
#     'great',
#     'normal',
#     'n’t scratchy',
#     'comfortable',
#     'big',
#     'little',
#     'durable',
#     'fits  perfectly',
#     'run tight',
#     'cool',
#     'casual',
#     'fantastic',
#     'not baggy',
#     'looks new',
#     'run little',
#     'true',
#     'not slim',
#     'hard',
#     'fit',
#     '’s durable'],
#    'shirts': ['thin'],
#    'fabric': ['not good', 'perfect amount'],
#    'magnates': ['biggest']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester']},
#   'score': 43.18181818181818},
#  {'id': 138,
#   'title': 'Not Today Loose Tee',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/af372b22-c2ce-45af-aea3-e477ad486faf.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['’s cute',
#     'soft',
#     'comfortable',
#     'not baggy',
#     'loose'],
#    'quality': ['nice'],
#    'motto': ['new'],
#    'fit': ['soft', 'nice', 'relaxed'],
#    'sizing': ['accurate'],
#    'material': ['soft']},
#   'detail': {'shirt': ['tee'],
#    'design': ['graphic', 'slogan'],
#    'fabric': ['polyester', 'rayon', 'triblend', 'cotton'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 151.5151515151515},
#  {'id': 143,
#   'title': 'Dream in Flowers Baby Graphic Tee',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/7e075034-43a6-4b90-bc74-c318e3345b5d.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'fabric': ['cotton'],
#    'design': ['graphic'],
#    'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short']},
#   'score': 2000.0},
#  {'id': 145,
#   'title': 'City Vibes Oversize T-Shirt',
#   'rating_div': {'5': 100, '4': 0, '3': 0, '2': 0, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/bf342a1e-d1de-48a8-a05e-d3cabfbe655e.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {},
#   'detail': {'shirt': ['tee'],
#    'knit': ['jersey'],
#    'design': ['raw edge'],
#    'neckline': ['v-neck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester', 'rayon', 'cotton']},
#   'score': 2000.0},
#  {'id': 146,
#   'title': 'Le Mid Rise V-Neck Tee',
#   'rating_div': {'5': 70, '4': 13, '3': 13, '2': 5, '1': 0},
#   'image': 'https://n.nordstrommedia.com/id/sr3/545393ae-82c7-4b9a-a7e8-9600ccc6a31c.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'material': ['thin', 'great'],
#    'complaint': ['only'],
#    'shirt': ['comfortable',
#     'great',
#     'drape  well',
#     'stylish',
#     'not true',
#     'fits not tight',
#     'drapes  well',
#     'super',
#     'sized',
#     'fit',
#     'fits loose',
#     'flattering'],
#    'cut': ['low'],
#    'fit': ['n’t flattering']},
#   'detail': {'shirt': ['tee'],
#    'fabric': ['pima', 'cotton'],
#    'neckline': ['v-neck'],
#    'sleeve': ['short']},
#   'score': 133.56996076966186},
#  {'id': 148,
#   'title': 'Classic Base Slim Fit T-Shirt',
#   'rating_div': {'5': 50, '4': 17, '3': 17, '2': 0, '1': 17},
#   'image': 'https://n.nordstrommedia.com/id/sr3/befed9ea-30a2-4187-86a0-587d3352136b.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'fitting': ['terrible'],
#    'shirt': ['little', 'tight', 'thin'],
#    'fit': ['large', 'nice', 'great', 'good'],
#    'fan': ['big'],
#    'material': ['nice'],
#    'price': ['more']},
#   'detail': {'fabric': ['cotton'],
#    'shirt': ['tee'],
#    'knit': ['jersey'],
#    'sleeve': ['short'],
#    'neckline': ['crewneck']},
#   'score': 10.829207920792078},
#  {'id': 150,
#   'title': 'Scotty Longline T-Shirt',
#   'rating_div': {'5': 51, '4': 27, '3': 5, '2': 3, '1': 14},
#   'image': 'https://n.nordstrommedia.com/id/sr3/4b7f7fb7-f719-4fba-b885-942367b00527.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['soft',
#     'everyday',
#     'comfortable',
#     'great',
#     'extra',
#     'wash great',
#     'thick',
#     'slimming',
#     'good',
#     '’s lengthy',
#     'little',
#     'runs small',
#     'not thin',
#     '’s able',
#     'fit',
#     'looking',
#     '’s slim',
#     'nice',
#     '’s fit'],
#    'fitting': ['slim'],
#    'material': ['good'],
#    'cut': ['nice'],
#    'quality': ['perfect', 'good'],
#    'shirts': ['amazing']},
#   'detail': {'shirt': ['tee'],
#    'neckline': ['crewneck'],
#    'sleeve': ['short'],
#    'fabric': ['polyester']},
#   'score': 81.70731707317073},
#  {'id': 151,
#   'title': 'Curved Hem Tee',
#   'rating_div': {'5': 25, '4': 28, '3': 23, '2': 17, '1': 7},
#   'image': 'https://n.nordstrommedia.com/id/sr3/17db0074-0efb-4263-887b-9b8b94fbd184.jpeg?crop=pad&pad_color=FFF&format=jpeg&w=780&h=1196',
#   'rev_summ': {'shirt': ['works  well',
#     'soft',
#     'comfy',
#     'not warm',
#     'great',
#     'not thin',
#     'runs small',
#     'fit',
#     'casual',
#     'nice'],
#    'fabric': ['soft', 'sheer'],
#    'fit': ['perfect', 'loose', 'great'],
#    'color': ['beautiful', 'great'],
#    'fan': ['huge'],
#    'hem': ['not long', 'long', 'low', 'not flattering'],
#    'arms': ['slim'],
#    'cami': ['necessary'],
#    'weather': ['chilly']},
#   'detail': {'shirt': ['tee'],
#    'hem': ['curved'],
#    'neckline': ['crewneck'],
#    'sleeve': ['long'],
#    'fabric': ['rayon', 'polyester', 'spandex']},
#   'score': 27.586206896551722}]

# %%
for item in dat
